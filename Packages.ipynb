# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# ...
#      --------------------------------------- 12.2/12.2 MB 13.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 18.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 181.6/181.6 kB 11.4 MB/s eta 0:00:00
# ...
#      ------------------------------------- 482.8/482.8 kB 29.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 96.8/96.8 kB 5.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 48.9/48.9 kB 2.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.0/7.0 MB 19.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.5
#     Uninstalling colorama-0.4.5:
#       Successfully uninstalled colorama-0.4.5
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#python -m spacy download en
# Out:
#   File "C:\Users\david\AppData\Local\Temp\ipykernel_1528\3004318277.py", line 1
#     python -m spacy download en
#               ^
# SyntaxError: invalid syntax

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\david\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
pip install gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gensim==3.8.3
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [636 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\gensim
#   copying gensim\downloader.py -> build\lib.win-amd64-cpython-39\gensim
#   copying gensim\interfaces.py -> build\lib.win-amd64-cpython-39\gensim
#   copying gensim\matutils.py -> build\lib.win-amd64-cpython-39\gensim
#   copying gensim\nosy.py -> build\lib.win-amd64-cpython-39\gensim
#   copying gensim\utils.py -> build\lib.win-amd64-cpython-39\gensim
#   copying gensim\__init__.py -> build\lib.win-amd64-cpython-39\gensim
#   creating build\lib.win-amd64-cpython-39\gensim\corpora
#   copying gensim\corpora\bleicorpus.py -> build\lib.win-amd64-cpython-39\gensim\corpora
#   copying gensim\corpora\csvcorpus.py -> build\lib.win-amd64-cpython-39\gensim\corpora
# ...

# %%
pip install fasttext
# Out:
# ...
#
# ...
#      ---------------------------------------- 68.8/68.8 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
# ...
#   Running setup.py clean for fasttext
# Failed to build fasttext
# ...
#   Running setup.py install for fasttext: started
#   Running setup.py install for fasttext: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [20 lines of output]
#   C:\Users\david\anaconda3\lib\site-packages\setuptools\dist.py:771: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#     warnings.warn(
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
# ...
